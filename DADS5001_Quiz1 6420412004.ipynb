# %%
import PySimpleGUI as sg
import pymongo
import json
from bson import ObjectId
import PySimpleGUI as sg
import pymongo
import json
from bson import ObjectId
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from pymongo import MongoClient
from matplotlib.backends.backend_tkagg import FigureCanvasTkAgg
import matplotlib.pyplot as plt
from tkinter import *
import certifi
ca = certifi.where()
client = pymongo.MongoClient("mongodb+srv://poomjew:KSJRezCUQNoUpMPL@cluster0.561ikzs.mongodb.net/?retryWrites=true&w=majority", tlsCAFile=ca)
db = client['db0']
collection = db["customer"]

f = open("D:\ป.โท\ป.โท เทอม 2\DADS5001\Quiz1\member_customer.json", "r")

#delete all documents in collection
collection.delete_many({})

# Add initial data to collection
for line in f:
    data = json.loads(line)
    collection.insert_one(data)

f.close()

# %%
#create data
def create():
          
    f = open("D:\ป.โท\ป.โท เทอม 2\DADS5001\Quiz1\member_customer.json", "r")

    for line in f:
        data = json.loads(line)


    
    while True:
        sg.theme('DarkPurple4')   
                
        layout = [  [sg.Text('Enter your Information')],
                    [sg.Text('Name'), sg.InputText()],
                    [sg.Text('Age'), sg.InputText(), sg.Text('Gender'), sg.InputCombo(('Male','Female'), size=(25, 2))],
                    [sg.Text('Nationality'), sg.InputCombo(('Thai','British','Chinese','Korean','Japanese','Argentinian','Portuguese'), size=(25, 1)), sg.Text('Occupation'), sg.InputCombo(('chef','Doctor','Farmer','Actor','Idol','Actress','Soccer','Singer'), size=(25, 1))],
                    [sg.Text('Salary'), sg.InputText()],
                    [sg.Button('Ok'), sg.Button('Cancel')] ]
        # Create the Window
        window = sg.Window('Nosql data management', layout)
        

        event, values = window.read()
        if event == sg.WIN_CLOSED or event == 'Cancel':
            break
        print('You entered ', values[0], values[1], values[2], values[3], values[4], values[5])
        
        
        
        #adding data to mongodb
        data['member_customer']['Name'] = values[0]
        data['member_customer']['Age'] = int(values[1])
        data['member_customer']['Gender'] = values[2] 
        data['member_customer']["Nationality"] = values[3]
        data['member_customer']["Occupation"] = values[4]
        data['member_customer']["Salary"] = int(values[5])
        #inserting data to mongodb
        collection.insert_one(data)



        print("Data inserted with record ids",data)
        sg.popup('Data inserted with record ids',data)
        window.close()
        break



    window.close()

# %%
#retrieve data from mongodb
def retrieve():
    
    f = open("D:\ป.โท\ป.โท เทอม 2\DADS5001\Quiz1\member_customer.json", "r")

    for line in f:
        data = json.loads(line)

    
    while True:
        sg.theme('DarkPurple4')   
        
        layout = [  [sg.Text("Enter your customer's name")],
                    [sg.Text('Name'), sg.InputText()],
                    [sg.Button('Ok'), sg.Button('Cancel')] ]
        
        window = sg.Window('Nosql data management', layout)

        event, values = window.read()
        if event == sg.WIN_CLOSED or event == 'Cancel': # if user closes window or clicks cancel
            break
        print('You entered ', values[0])
        #searching data from mongodb
        query = {"member_customer.Name" : values[0]}
        mydoc = collection.find(query)

        for x in mydoc:
            print(x)
            sg.popup(x)
            window.close()
            break
        else:
            print("No record found")
            sg.popup('No record found, try again')
            window.close()
            continue
        window.close()
        break



    window.close()

# %%
#update data in mongodb
def update():
    
    f = open("D:\ป.โท\ป.โท เทอม 2\DADS5001\Quiz1\member_customer.json", "r")

    for line in f:
        data = json.loads(line)

    
    while True:
        sg.theme('DarkPurple4')   
        
        layout = [  [sg.Text("What is your customer's name?")],
                    [sg.Text('Name'), sg.InputText()],
                    [sg.Button('Ok'), sg.Button('Cancel')] ]
        
        window = sg.Window('Nosql data management', layout)

        event, values = window.read()
        if event == sg.WIN_CLOSED or event == 'Cancel': # if user closes window or clicks cancel
            break
        print('You entered ', values[0])
        
        query = {"member_customer.Name" : values[0]}
        mydoc = collection.find(query)

        for x in mydoc:
            print(x)
            sg.popup(x)
            window.close()
            break
        else:
            print("No record found")
            sg.popup('No record found, try again')
            window.close()
            continue
        window.close()
        
        layout = [  [sg.Text('Enter your new Information')],
                    [sg.Text('Name'), sg.InputText()],
                    [sg.Text('Age'), sg.InputText(), sg.Text('Gender'), sg.InputCombo(('Male','Female'), size=(25, 2))],
                    [sg.Text('Nationality'), sg.InputCombo(('Thai','British','Chinese','Korean','Japanese','Argentinian','Portuguese'), size=(25, 1)), sg.Text('Occupation'), sg.InputCombo(('chef','Doctor','Farmer','Actor','Idol','Actress','Soccer','Singer'), size=(25, 1))],
                    [sg.Text('Salary'), sg.InputText()],
                    [sg.Button('Ok'), sg.Button('Cancel')] ]
        
        window = sg.Window('Nosql data management', layout)

        event, values = window.read()
        if event == sg.WIN_CLOSED or event == 'Cancel': # if user closes window or clicks cancel
            break
        print('You entered ', values[0], values[1], values[2], values[3], values[4], values[5])

        

        #adding data with dict to mongodb
        data['member_customer']['Name'] = values[0]
        data['member_customer']['Age'] = int(values[1])
        data['member_customer']['Gender'] = values[2] 
        data['member_customer']["Nationality"] = values[3]
        data['member_customer']["Occupation"] = values[4]
        data['member_customer']["Salary"] = int(values[5])
        
        #update data
        newvalues = { "$set": data }
        mydoc = collection.update_one(query,newvalues)
        print(mydoc.modified_count, "record(s) updated")
        sg.popup(mydoc.modified_count, "record(s) updated")
        window.close()
        continue
        

    window.close()

# %%
#delete data from mongodb
def delete():
    
    f = open("D:\ป.โท\ป.โท เทอม 2\DADS5001\Quiz1\member_customer.json", "r")

    for line in f:
        data = json.loads(line)

    
    while True:
        sg.theme('DarkPurple4')   
        
        layout = [  [sg.Text("What is your customer's name?")],
                    [sg.Text('Name'), sg.InputText()],
                    [sg.Button('Ok'), sg.Button('Cancel')] ]
        
        window = sg.Window('Nosql data management', layout)

        event, values = window.read()
        if event == sg.WIN_CLOSED or event == 'Cancel': # if user closes window or clicks cancel
            break
        print('You entered ', values[0])
        
        query = {"member_customer.Name" : values[0]}
        mydoc = collection.find(query)


        for x in mydoc:
            print(x)
            sg.popup(x)
            window.close()
            break
        else:
            print("No record found")
            sg.popup('No record found')
            window.close()
            break

        #deleting data to mongodb
        query = {"member_customer.Name" : values[0]}
        mydoc = collection.delete_one(query)
        print(mydoc.deleted_count, "record(s) deleted")
        sg.popup(mydoc.deleted_count, "record(s) deleted")
        window.close()
        break





    window.close()

# %%
#crud gui

ca = certifi.where()
client = pymongo.MongoClient("mongodb+srv://poomjew:KSJRezCUQNoUpMPL@cluster0.561ikzs.mongodb.net/?retryWrites=true&w=majority", tlsCAFile=ca)
db = client['db0']
collection = db["customer"]

layout = [[sg.Text('What do you want to do?')],
          [sg.Button('Create'),sg.Button('Retrieve')],
          [sg.Button('Update'),sg.Button('Delete')],
          [sg.Button('Exit')]]



window = sg.Window('Nosql data management', layout,finalize=True)
window.maximize()

while True:  # Event Loop
    event, values = window.read()
    if event == sg.WIN_CLOSED or event == 'Exit':
        break
    if event == 'Create':
        create()
    if event == 'Retrieve':
        retrieve()
    if event == 'Update':
        update()
    if event == 'Delete':
        delete()
    
        

window.close()
# Out:
# You entered  pooss 50 Male British Doctor 50000
# Data inserted with record ids {'member_customer': {'Name': 'pooss', 'Age': 50, 'Gender': 'Male', 'Nationality': 'British', 'Occupation': 'Doctor', 'Salary': 50000}, '_id': ObjectId('63875bc22e0d36a137b6d941')}
